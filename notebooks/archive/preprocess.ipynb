# %% [markdown]
# ## Income Classification Data Preprocessing Workflow
#
# This notebook demonstrates a step-by-step data preprocessing pipeline for an income classification dataset.

# %%
# Import Required Libraries
import pandas as pd
import numpy as np

# %%
# Load the Dataset
data = pd.read_csv("../data/income.csv", na_values='?')
print("Initial shape:", data.shape)
